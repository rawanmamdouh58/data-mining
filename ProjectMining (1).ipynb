# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("fueltype.csv")
df = df.loc[:,("brand","bodyType","year","transmission","power","fuelType")]

# %%
df
# Out:
#               brand           bodyType    year transmission  power  fuelType
# 0            Toyota       jeep 5 doors  1995.0           AT  130.0    Diesel
# 1            Toyota       jeep 5 doors     NaN    Automatic  286.0    Diesel
# 2            Toyota  hatchback 5 doors  2019.0          CVT   95.0  Gasoline
# 3            Toyota              sedan  2002.0           AT  160.0  Gasoline
# 4            Toyota       jeep 5 doors  2010.0           AT  170.0  Gasoline
# ...             ...                ...     ...          ...    ...       ...
# 1048570      Nissan       jeep 5 doors     NaN       Manual  125.0    Diesel
# 1048571      Nissan      station wagon     NaN    Automatic  130.0  Gasoline
# 1048572       Honda       jeep 5 doors  2015.0        Robot  132.0  Gasoline
# 1048573      Subaru       jeep 5 doors     NaN    Automatic  137.0  Gasoline
# 1048574  Mitsubishi       jeep 3 doors     NaN       Manual  145.0  Gasoline
#
# [1048575 rows x 6 columns]

# %%
df.shape
# Out:
# (1048575, 6)

# %%
#Histogram
sns.histplot(data=df['year'], bins=30)
# Out:
# C:\Users\AlDawlia\anaconda3\envs\envname\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='year', ylabel='Count'>

# %%
#lineplot
sns.lineplot(x='brand', y='year', data=df)
# Out:
# C:\Users\AlDawlia\anaconda3\envs\envname\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\AlDawlia\anaconda3\envs\envname\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='brand', ylabel='year'>

# %%
#PreProcessing
df.dtypes
# Out:
# brand            object
# bodyType         object
# year            float64
# transmission     object
# power           float64
# fuelType         object
# dtype: object

# %%
df.describe()
# Out:
#                 year         power
# count  639667.000000  1.038407e+06
# mean     2005.270028  1.586784e+02
# std         8.219167  7.150545e+01
# min      1953.000000  4.500000e+01
# 25%      1999.000000  1.070000e+02
# 50%      2006.000000  1.400000e+02
# 75%      2012.000000  1.840000e+02
# max      2021.000000  6.500000e+02

# %%
#SUM OF NAN VALUES
print(df.isnull().sum())
# Out:
# brand                0
# bodyType             0
# year            408908
# transmission      5432
# power            10168
# fuelType          4420
# dtype: int64

# %%
#Drop NAN
df.dropna(inplace=True)

# %%
#Test NAN
print(df.isnull().sum())
# Out:
# brand           0
# bodyType        0
# year            0
# transmission    0
# power           0
# fuelType        0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0          False
# 2          False
# 3          False
# 4          False
# 8          False
#            ...
# 1048563     True
# 1048565     True
# 1048567     True
# 1048568     True
# 1048572     True
# Length: 639254, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated()
# Out:
# 0          False
# 2          False
# 3          False
# 4          False
# 8          False
#            ...
# 1043509    False
# 1047489    False
# 1047490    False
# 1047491    False
# 1047493    False
# Length: 1433, dtype: bool

# %%
df
# Out:
#               brand           bodyType    year transmission  power  fuelType
# 0            Toyota       jeep 5 doors  1995.0           AT  130.0    Diesel
# 2            Toyota  hatchback 5 doors  2019.0          CVT   95.0  Gasoline
# 3            Toyota              sedan  2002.0           AT  160.0  Gasoline
# 4            Toyota       jeep 5 doors  2010.0           AT  170.0  Gasoline
# 8            Hummer       jeep 5 doors  2002.0           AT  315.0  Gasoline
# ...             ...                ...     ...          ...    ...       ...
# 1043509  Mitsubishi      station wagon  1997.0       Manual   88.0    Diesel
# 1047489         Kia       jeep 5 doors  2002.0           AT  145.0    Diesel
# 1047490       Honda              sedan  1999.0       Manual  200.0  Gasoline
# 1047491      Nissan      station wagon  1997.0           AT  200.0  Gasoline
# 1047493      Subaru              sedan  1994.0       Manual  275.0  Gasoline
#
# [1433 rows x 6 columns]

# %%
#lineplot
sns.lineplot(x='brand', y='year', data=df)
# Out:
# C:\Users\AlDawlia\anaconda3\envs\envname\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\AlDawlia\anaconda3\envs\envname\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='brand', ylabel='year'>

# %%
#Histogram
sns.histplot(data=df['year'], bins=30)
# Out:
# C:\Users\AlDawlia\anaconda3\envs\envname\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='year', ylabel='Count'>

# %%
#Histogram
sns.histplot(data=df['brand'], bins=30)
# Out:
# C:\Users\AlDawlia\anaconda3\envs\envname\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='brand', ylabel='Count'>

# %%
#Histogram
sns.histplot(data=df['fuelType'], bins=30)
# Out:
# C:\Users\AlDawlia\anaconda3\envs\envname\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='fuelType', ylabel='Count'>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
#هحولهم لأرقام
#df.brand = le.fit_transform(df.brand)
df.transmission = le.fit_transform(df.transmission)
df.bodyType = le.fit_transform(df.bodyType)
df.fuelType = le.fit_transform(df.fuelType)

# %%
df
# Out:
#               brand  bodyType    year  transmission  power  fuelType
# 0            Toyota         4  1995.0             0  130.0         0
# 2            Toyota         2  2019.0             1   95.0         1
# 3            Toyota         9  2002.0             0  160.0         1
# 4            Toyota         4  2010.0             0  170.0         1
# 8            Hummer         4  2002.0             0  315.0         1
# ...             ...       ...     ...           ...    ...       ...
# 1043509  Mitsubishi        10  1997.0             2   88.0         0
# 1047489         Kia         4  2002.0             0  145.0         0
# 1047490       Honda         9  1999.0             2  200.0         1
# 1047491      Nissan        10  1997.0             0  200.0         1
# 1047493      Subaru         9  1994.0             2  275.0         1
#
# [1433 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

# %%
#BarPlot
fig, ax = plt.subplots(figsize=(14, 9))
# Create a boxplot using Seaborn
sns.barplot(x='brand', y='fuelType', data=df , ax=ax)
plt.show()

# %%
# Create a figure and axis with specified size
fig, ax = plt.subplots(figsize=(14, 9))
# Create a boxplot using Seaborn
#Histogram
sns.boxplot(data=df['power'], ax=ax)
plt.show()

# %%
le = LabelEncoder()
df.brand = le.fit_transform(df.brand)
df
# Out:
#          brand  bodyType    year  transmission  power  fuelType
# 0           34         4  1995.0             0  130.0         0
# 2           34         2  2019.0             1   95.0         1
# 3           34         9  2002.0             0  160.0         1
# 4           34         4  2010.0             0  170.0         1
# 8           13         4  2002.0             0  315.0         1
# ...        ...       ...     ...           ...    ...       ...
# 1492463     10         9  2006.0             2  137.0         1
# 1492475     25         6  1997.0             0  125.0         0
# 1494056     34         2  2012.0             1  105.0         1
# 1494061     27         2  2006.0             0  109.0         1
# 1497238     27         4  2007.0             2  106.0         0
#
# [1613 rows x 6 columns]

# %%
df[['year','power']] = df[['year','power']].astype(int)
df
# Out:
#          brand  bodyType  year  transmission  power  fuelType
# 0           34         4  1995             0    130         0
# 2           34         2  2019             1     95         1
# 3           34         9  2002             0    160         1
# 4           34         4  2010             0    170         1
# 8           13         4  2002             0    315         1
# ...        ...       ...   ...           ...    ...       ...
# 1492463     10         9  2006             2    137         1
# 1492475     25         6  1997             0    125         0
# 1494056     34         2  2012             1    105         1
# 1494061     27         2  2006             0    109         1
# 1497238     27         4  2007             2    106         0
#
# [1613 rows x 6 columns]

# %%
#decisionTree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import tree
import matplotlib as plt
data_X = df.iloc[:, :-1]
data_Y = df.iloc[:, -1]
x_train, x_test, y_train, y_test = train_test_split(data_X, data_Y, test_size=0.2)
#by entropy
dt = DecisionTreeClassifier(criterion="entropy")
#training
dt.fit(x_train,y_train)
#predict
pred = dt.predict(x_test)
accuracy = accuracy_score(y_test, pred)
print("Accuracy:", accuracy)
dots=StringIO()
export_graphviz(dt,out_file=dots,filled=True,rounded=True,feature_names= data_X.columns,class_names=["Diesel","Gasoline"])
graph =  pydotplus.graph_from_dot_data(dots.getvalue())
graph.write_png("tree.png")
Image(graph.create_png())

# %%
data_X = df.iloc[:, :-1]
data_Y = df.iloc[:, -1]

# %%
x_train, x_test, y_train, y_test = train_test_split(data_X, data_Y, test_size=0.2)

# %%
#by entropy
dt = DecisionTreeClassifier(criterion="entropy")
#training
dt.fit(x_train,y_train)
#predict
pred = dt.predict(x_test)

# %%
accuracy = accuracy_score(y_test, pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.913312693498452

# %%
from six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus

# %%
dots=StringIO()
export_graphviz(dt,out_file=dots,filled=True,rounded=True,feature_names= data_X.columns,class_names=["Diesel","Gasoline"])
graph =  pydotplus.graph_from_dot_data(dots.getvalue())
graph.write_png("tree.png")
Image(graph.create_png())
# Out:
# (process:2560): GLib-GIO-WARNING **: 23:15:26.752: Unexpectedly, UWP app `Clipchamp.Clipchamp_2.8.3.0_neutral__yxz26nhyzhsrt' (AUMId `Clipchamp.Clipchamp_yxz26nhyzhsrt!App') supports 41 extensions but has no verbs

# %%
#Knn
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)
pred = knn.predict(x_test)
accuracy = accuracy_score(y_test, pred)
print("Accuracy:", accuracy)
#Confusion Matrix
from sklearn import metrics
actual = y_test
predicted = pred
confusion_matrix = metrics.confusion_matrix(actual, predicted)
conMat_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False,True])
import matplotlib.pyplot as plt
conMat_display.plot()
plt.show()

# %%
knn.fit(x_train, y_train)
pred = knn.predict(x_test)

# %%
accuracy = accuracy_score(y_test, pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8947368421052632

# %%
#Confusion Matrix
from sklearn import metrics
actual = y_test
predicted = pred
confusion_matrix = metrics.confusion_matrix(actual, predicted)

# %%
conMat_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False,True])

# %%
import matplotlib.pyplot as plt
conMat_display.plot()
plt.show()

# %%
Accuracy = metrics.accuracy_score(actual, predicted)
print({'Accuracy':Accuracy})
Precision = metrics.precision_score(actual, predicted)
print({'Precision':Precision})
Recall = metrics.recall_score(actual, predicted)
print({'Recall':Recall})
F1_score = metrics.f1_score(actual, predicted)
print({'F1_score':F1_score})
# Out:
# {'Accuracy': 0.8947368421052632}
# {'Precision': 0.9401408450704225}
# {'Recall': 0.9401408450704225}
# {'F1_score': 0.9401408450704225}

# %%
 

from mlxtend.plotting import plot_decision_regions
import numpy as np

# %%
from sklearn.decomposition import PCA 

pca = PCA(n_components=2)
reduced_train_data = pca.fit_transform(x_train) #2D بحوله

knn_again = KNeighborsClassifier(n_neighbors=3)
knn_again.fit(reduced_train_data, y_train)

reduced_test_data = pca.transform(x_test)
pred_reduced = knn_again.predict(reduced_test_data)
y_test_array = np.array(y_test)
plot_decision_regions(reduced_test_data, y_test_array, clf=knn_again, legend=2)
# Out:
# <Axes: >

# %%
data_X_arr = np.array(data_X)
data_Y_arr = np.array(data_Y)

selected_features = data_X_arr[:, [1, 4]]  # body , Power

knn2 = KNeighborsClassifier(n_neighbors=3)
knn2.fit(selected_features, data_Y_arr)
plot_decision_regions(selected_features, data_Y_arr, clf=knn2, legend=2)
# Out:
# <Axes: >

# %%
##ensemble learning

# %%
##stacking
from sklearn.ensemble import StackingClassifier

from sklearn.linear_model import LogisticRegression
base_estimators = [
  ('dt', dt),
    ('knn', knn)
]
stacking_clf = StackingClassifier(estimators=base_estimators, final_estimator=LogisticRegression())

abc=stacking_clf.fit(x_train, y_train)
a= abc.predict(x_test)

print("Accuracy:", accuracy_score(y_test, a))
# Out:
# Accuracy: 0.9219330855018587

# %%
##bagging1
from sklearn.model_selection import cross_val_score, cross_validate, RepeatedKFold
from sklearn.ensemble import BaggingClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
clf_dict = {}
clf_dict['dt'] = dt
clf_dict['knn'] = knn


clf_acc = {}
bag_acc = {}
folds, n_reps = 10,10
n_est = 2
v = 0
for c_name in clf_dict.keys():
    pipe  = Pipeline(steps=[
                           ('classifier', clf_dict[c_name])])
    clf_cv = cross_validate(pipe, data_X, data_Y,  n_jobs=-1,
                                    cv=RepeatedKFold(n_splits=folds, n_repeats=n_reps))

    the_bag = BaggingClassifier(pipe, 
                            n_estimators = n_est,
                            max_samples = 1.0, # bootstrap resampling 
                            bootstrap = True)
    bag_cv = cross_validate(the_bag, data_X, data_Y,  n_jobs=-1,
                                    cv=RepeatedKFold(n_splits=folds, n_repeats=n_reps))
    
    clf_acc[c_name] = clf_cv['test_score'].mean()
    bag_acc[c_name] = bag_cv['test_score'].mean()
    print("Mean for {:s} {:.2f}".format(c_name, clf_cv['test_score'].mean()))
    print("Mean for {:s} bag {:.2f}".format(c_name, bag_cv['test_score'].mean()))
clf_acc
# Out:
# Mean for dt 0.91
# Mean for dt bag 0.89
# Mean for knn 0.91
# Mean for knn bag 0.90
# {'dt': 0.9139417989417989, 'knn': 0.9098512384019632}

# %%
import numpy as np
names = clf_dict.keys()
y_pos = np.arange(len(names))
f = plt.figure(figsize=(7,6))
plt.bar(y_pos-0.15, clf_acc.values(), align='center', width = 0.3, alpha=0.5, 
        label = "Classifier")
plt.bar(y_pos+0.15, bag_acc.values(), align='center', color = 'r', width = 0.3, alpha=0.5,
       label = "Ensemble")
plt.xticks(y_pos, names)
plt.ylabel('Accuracy')
#plt.xlabel(x_lab)
#plt.title(title)
plt.ylim((0.5,1))
plt.grid(axis = 'y')
plt.legend(loc = 'lower right')
plt.show()
f.savefig('bag-est-bar.pdf')

# %%
##bagging2
dtree_bag = BaggingClassifier(base_estimator=dt)
knn_bag = BaggingClassifier(base_estimator=knn)

base_estimators = [
    ('tree', dtree_bag),
    ('knn',knn_bag)
]


stacking_clf = StackingClassifier(
    estimators=base_estimators,
    final_estimator=LogisticRegression()  
)
abc=stacking_clf.fit(x_train, y_train)
a= abc.predict(x_test)

print("Accuracy:", accuracy_score(y_test, a))
# Out:
# C:\Users\AlDawlia\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\AlDawlia\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\AlDawlia\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\AlDawlia\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\AlDawlia\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# ...

# %%
##bagging by RF
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(criterion = 'entropy', n_estimators = 100)
model.fit(x_train, y_train)
print(accuracy_score(y_test, model.predict(x_test)))
# Out:
# 0.9312267657992565

# %%
#PreProcessing
df.dtypes
df.describe()
#SUM OF NAN VALUES
print(df.isnull().sum())
#Test NAN
print(df.isnull().sum())
df.duplicated()
df.drop_duplicates(inplace=True)
df.duplicated()
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #PreProcessing
# ----> 2 df.dtypes
#
# NameError: name 'df' is not defined

# %%
df.describe()
